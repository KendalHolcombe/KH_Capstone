# %%
import pandas as pd

# %%
# Collect metadata
train_df = pd.read_csv('crime_query.csv')
h_df = pd.read_csv('hosp_query.csv')
f_df = pd.read_csv('fire_query.csv')
pop_df = pd.read_csv('census_population.csv')

## Add metadata to train_df

# %%
# Crime Count by county
tmp_df = train_df.groupby(['county']).incident_id.agg('count')
tmp_df = tmp_df.to_frame().reset_index()
tmp_df = tmp_df.rename({'incident_id': 'crime_cnt'}, axis='columns')
train_df = train_df.join(tmp_df.set_index('county'), on='county')

# %%
train_df.head().T
# Out:
#                                        0                         1  \
# incident_id                     67693343                  67693344
# year                                2013                      2013
# age_num                               46                        57
# victim_sex                             F                         M
# crime_against                   Property                  Property
# offense                All Other Larceny  Theft From Motor Vehicle
# offense_category  Larceny/Theft Offenses    Larceny/Theft Offenses
# location_id                           20                        18
# location_name             Residence/Home   Parking/Drop Lot/Garage
# county                            POTTER                    POTTER
# officers                             343                       343
# civilians                             68                        68
# crime_cnt                          47721                     47721
#
#                                          2                           3  \
# incident_id                       67693345                    67693346
# year                                  2013                        2013
# age_num                                 51                          24
# victim_sex                               F                           M
# crime_against                     Property                    Property
# offense           Theft From Motor Vehicle           All Other Larceny
# offense_category    Larceny/Theft Offenses      Larceny/Theft Offenses
# location_id                             18                           5
# location_name      Parking/Drop Lot/Garage  Commercial/Office Building
# county                              POTTER                      POTTER
# officers                               343                         343
# civilians                               68                          68
# crime_cnt                            47721                       47721
#
#                                              4
# incident_id                           67693348
# year                                      2013
# age_num                                     49
# victim_sex                                   M
# crime_against                         Property
# offense           Burglary/Breaking & Entering
# offense_category  Burglary/Breaking & Entering
# location_id                                 20
# location_name                   Residence/Home
# county                                  POTTER
# officers                                   343
# civilians                                   68
# crime_cnt                                47721

# %%
# Hospital Count by county
tmp_df2 = h_df.groupby(['county']).hosp_id.agg('count')
tmp_df2 = tmp_df2.to_frame().reset_index()
tmp_df2 = tmp_df2.rename({'hosp_id': 'hosp_cnt'}, axis='columns')

# %%
tmp_df2.head()
# Out:
#      county  hosp_cnt
# 0  ANDERSON         1
# 1   ANDREWS         1
# 2  ANGELINA         2
# 3  ATASCOSA         1
# 4    AUSTIN         1

# %%
# Total Bed Count by county
h_df['beds'] = h_df['beds'].clip_lower(1)
tmp_df3 = h_df.groupby(['county']).beds.agg('sum')
tmp_df3 = tmp_df3.to_frame().reset_index()
tmp_df3 = tmp_df3.rename({'beds': 'bed_cnt'}, axis='columns')
h_df = tmp_df2.join(tmp_df3.set_index('county'), on='county')

# %%
h_df.head()
# Out:
#      county  hosp_cnt  bed_cnt
# 0  ANDERSON         1     86.0
# 1   ANDREWS         1     34.0
# 2  ANGELINA         2    420.0
# 3  ATASCOSA         1     67.0
# 4    AUSTIN         1     32.0

# %%
# Fire Station Count by county
tmp_df4 = f_df.groupby(['county']).fire_id.agg('count')
tmp_df4 = tmp_df4.to_frame().reset_index()
tmp_df4 = tmp_df4.rename({'fire_id': 'fire_cnt'}, axis='columns')
hf_df = tmp_df4.join(h_df.set_index('county'), on='county')

# %%
hf_df.head()
# Out:
#      county  fire_cnt  hosp_cnt  bed_cnt
# 0  ANDERSON        21       1.0     86.0
# 1   ANDREWS         1       1.0     34.0
# 2  ANGELINA        18       2.0    420.0
# 3   ARANSAS         5       NaN      NaN
# 4    ARCHER         7       NaN      NaN

# %%
# Join to train_df
train_df = train_df.join(hf_df.set_index('county'), on='county')

# %%
train_df.head().T
# Out:
#                                        0                         1  \
# incident_id                     67693343                  67693344
# year                                2013                      2013
# age_num                               46                        57
# victim_sex                             F                         M
# crime_against                   Property                  Property
# offense                All Other Larceny  Theft From Motor Vehicle
# offense_category  Larceny/Theft Offenses    Larceny/Theft Offenses
# location_id                           20                        18
# location_name             Residence/Home   Parking/Drop Lot/Garage
# county                            POTTER                    POTTER
# officers                             343                       343
# civilians                             68                        68
# crime_cnt                          47721                     47721
# fire_cnt                              12                        12
# hosp_cnt                               5                         5
# bed_cnt                              878                       878
#
#                                          2                           3  \
# incident_id                       67693345                    67693346
# year                                  2013                        2013
# age_num                                 51                          24
# victim_sex                               F                           M
# crime_against                     Property                    Property
# offense           Theft From Motor Vehicle           All Other Larceny
# offense_category    Larceny/Theft Offenses      Larceny/Theft Offenses
# location_id                             18                           5
# location_name      Parking/Drop Lot/Garage  Commercial/Office Building
# county                              POTTER                      POTTER
# officers                               343                         343
# civilians                               68                          68
# crime_cnt                            47721                       47721
# fire_cnt                                12                          12
# hosp_cnt                                 5                           5
# bed_cnt                                878                         878
#
#                                              4
# incident_id                           67693348
# year                                      2013
# age_num                                     49
# victim_sex                                   M
# crime_against                         Property
# offense           Burglary/Breaking & Entering
# offense_category  Burglary/Breaking & Entering
# location_id                                 20
# location_name                   Residence/Home
# county                                  POTTER
# officers                                   343
# civilians                                   68
# crime_cnt                                47721
# fire_cnt                                    12
# hosp_cnt                                     5
# bed_cnt                                    878

# %%
# Bring in census populations
pop_df['county'] = pop_df['county'].str.upper()
train_df = pd.merge(train_df, pop_df, how='outer', on=['county', 'year'])
train_df['population_description'] = pd.cut(train_df['population'], [0, 25000, 100000, 500000, 10000000],
                                            labels=['Under 25,000', '25,000 - 99,999', '100,000 - 499,999',
                                                    'Over 500,000'])

# %%
train_df.head().T
# Out:
#                                              0                         1  \
# incident_id                        6.76933e+07               6.76933e+07
# year                                      2013                      2013
# age_num                                     46                        57
# victim_sex                                   F                         M
# crime_against                         Property                  Property
# offense                      All Other Larceny  Theft From Motor Vehicle
# offense_category        Larceny/Theft Offenses    Larceny/Theft Offenses
# location_id                                 20                        18
# location_name                   Residence/Home   Parking/Drop Lot/Garage
# county                                  POTTER                    POTTER
# officers                                   343                       343
# civilians                                   68                        68
# crime_cnt                                47721                     47721
# fire_cnt                                    12                        12
# hosp_cnt                                     5                         5
# bed_cnt                                    878                       878
# population                              122088                    122088
# population_description       100,000 - 499,999         100,000 - 499,999
#
#                                                2                           3  \
# incident_id                          6.76933e+07                 6.76933e+07
# year                                        2013                        2013
# age_num                                       51                          24
# victim_sex                                     F                           M
# crime_against                           Property                    Property
# offense                 Theft From Motor Vehicle           All Other Larceny
# offense_category          Larceny/Theft Offenses      Larceny/Theft Offenses
# location_id                                   18                           5
# location_name            Parking/Drop Lot/Garage  Commercial/Office Building
# county                                    POTTER                      POTTER
# officers                                     343                         343
# civilians                                     68                          68
# crime_cnt                                  47721                       47721
# fire_cnt                                      12                          12
# hosp_cnt                                       5                           5
# bed_cnt                                      878                         878
# population                                122088                      122088
# population_description         100,000 - 499,999           100,000 - 499,999
#
#                                                    4
# incident_id                              6.76933e+07
# year                                            2013
# age_num                                           49
# victim_sex                                         M
# crime_against                               Property
# offense                 Burglary/Breaking & Entering
# offense_category        Burglary/Breaking & Entering
# location_id                                       20
# location_name                         Residence/Home
# county                                        POTTER
# officers                                         343
# civilians                                         68
# crime_cnt                                      47721
# fire_cnt                                          12
# hosp_cnt                                           5
# bed_cnt                                          878
# population                                    122088
# population_description             100,000 - 499,999

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 464978 entries, 0 to 464977
# Data columns (total 18 columns):
# incident_id               463095 non-null float64
# year                      464978 non-null int64
# age_num                   456081 non-null float64
# victim_sex                463095 non-null object
# crime_against             463095 non-null object
# offense                   463095 non-null object
# offense_category          463095 non-null object
# location_id               463095 non-null float64
# location_name             463095 non-null object
# county                    464978 non-null object
# officers                  463095 non-null float64
# civilians                 463095 non-null float64
# crime_cnt                 463095 non-null float64
# fire_cnt                  463095 non-null float64
# hosp_cnt                  461467 non-null float64
# bed_cnt                   461467 non-null float64
# population                464190 non-null float64
# population_description    464190 non-null category
# dtypes: category(1), float64(10), int64(1), object(6)
# memory usage: 64.3+ MB

# %%
train_df['population_description'].value_counts()
# Out:
# Over 500,000         262781
# 100,000 - 499,999    155742
# 25,000 - 99,999       39421
# Under 25,000           6246
# Name: population_description, dtype: int64
