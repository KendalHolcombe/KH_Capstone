# %%
from Query_Script import Query_to_DF

# %%
query = 'SELECT * from cde_agencies'

# %%
df = Query_to_DF(query)

# %%
df
# Out:
#       agency_id        ori legacy_ori  \
# 0         19027  TX0572100  TX0572100
# 1         19313  TX1080500  TX1080500
# 2         19409  TX1290000  TX1290000
# 3         25575  TX2401000  TX2401000
# 4         19478  TX1520800  TX1520800
# 5         19541  TX1700100  TX1700100
# 6         18968  TX0431800  TX0431800
# 7         19185  TX0880000  TX0880000
# 8         19373  TX1200000  TX1200000
# 9         19792  TX2350000  TX2350000
# 10        18798  TX0140700  TX0140700
# 11        19410  TX1290100  TX1290100
# 12        19605  TX1870000  TX1870000
# 13        19676  TX2120200  TX2120200
# 14        19444  TX1410100  TX1410100
# 15        19311  TX1080300  TX1080300
# 16        19368  TX1170100  TX1170100
# 17        19562  TX1740000  TX1740000
# 18        19768  TX2273600  TX2273600
# 19        19472  TX1520000  TX1520000
# 20        19491  TX1550400  TX1550400
# 21        19678  TX2120400  TX2120400
# 22        19644  TX2010000  TX2010000
# ...
