# %%
import pandas as pd
import gmaps

# %%
gmaps.configure(api_key="AIzaSyBc6ZAVMRUiGV3hVt1wcO0m2QB8ogxbEiU")

# %%
data = pd.read_csv('Texas_Counties_Centroid_Map.csv')
counts = pd.read_csv('heatmap.csv')

# %%
data.head()
# Out:
#      X (Lat)   Y (Long)  CNTY_NM   FIPS  Shape_Leng  Shape_Area
# 0 -97.515000  26.138477  Cameron  48061    6.776491    0.237848
# 1 -97.643033  26.471329  Willacy  48489    3.324169    0.155451
# 2 -98.738349  26.562126    Starr  48427    2.600375    0.288492
# 3 -98.180887  26.396627  Hidalgo  48215    3.310210    0.370852
# 4 -98.218741  27.031567   Brooks  48047    2.056815    0.222311

# %%
counts.head()
# Out:
#      County  Incident Count
# 0      BELL            3248
# 1     BEXAR             360
# 2  BRAZORIA            2656
# 3  BREWSTER              61
# 4    BURNET             290

# %%
data['CNTY_NM'] = data['CNTY_NM'].str.upper()

# %%
data.head()
# Out:
#      X (Lat)   Y (Long)  CNTY_NM   FIPS  Shape_Leng  Shape_Area
# 0 -97.515000  26.138477  CAMERON  48061    6.776491    0.237848
# 1 -97.643033  26.471329  WILLACY  48489    3.324169    0.155451
# 2 -98.738349  26.562126    STARR  48427    2.600375    0.288492
# 3 -98.180887  26.396627  HIDALGO  48215    3.310210    0.370852
# 4 -98.218741  27.031567   BROOKS  48047    2.056815    0.222311

# %%
heatmap =pd.merge(data, counts, how = 'left', left_on='CNTY_NM', right_on='County')

# %%
heatmap.head()
# Out:
#      X (Lat)   Y (Long)  CNTY_NM   FIPS  Shape_Leng  Shape_Area   County  \
# 0 -97.515000  26.138477  CAMERON  48061    6.776491    0.237848  CAMERON
# 1 -97.643033  26.471329  WILLACY  48489    3.324169    0.155451  WILLACY
# 2 -98.738349  26.562126    STARR  48427    2.600375    0.288492    STARR
# 3 -98.180887  26.396627  HIDALGO  48215    3.310210    0.370852  HIDALGO
# 4 -98.218741  27.031567   BROOKS  48047    2.056815    0.222311      NaN
#
#    Incident Count
# 0             2.0
# 1           103.0
# 2            30.0
# 3           290.0
# 4             NaN

# %%
heatmap.drop(['CNTY_NM','FIPS','Shape_Leng','Shape_Area'], axis=1, inplace=True)
heatmap.head()
# Out:
#      X (Lat)   Y (Long)   County  Incident Count
# 0 -97.515000  26.138477  CAMERON             2.0
# 1 -97.643033  26.471329  WILLACY           103.0
# 2 -98.738349  26.562126    STARR            30.0
# 3 -98.180887  26.396627  HIDALGO           290.0
# 4 -98.218741  27.031567      NaN             NaN

# %%
locations = heatmap[['X (Lat)', 'Y (Long)']]
weights = heatmap['Incident Count']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# ---------------------------------------------------------------------------
# InvalidPointException                     Traceback (most recent call last)
# <ipython-input-15-e70c97222edd> in <module>()
#       2 weights = heatmap['Incident Count']
#       3 fig = gmaps.figure()
# ----> 4 fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
#       5 fig
#
# ~/anaconda3/lib/python3.6/site-packages/gmaps/heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~/anaconda3/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     407         """Public constructor"""
#     408         self._model_id = kwargs.pop('model_id', None)
# --> 409         super(Widget, self).__init__(**kwargs)
#     410
# ...
