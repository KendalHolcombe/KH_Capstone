# %%
import numpy as np
import pandas as pd
import psycopg2

# %%
import json

with open('config.json') as f:
    conf = json.load(f)
    host = conf['host']
    database = conf['database']
    user = conf['user']
    passw = conf['passw']

# %%
conn_str = "host={} dbname={} user={} password={}".format(host, database, user, passw)
conn = psycopg2.connect(conn_str)

# %%
query = '''
SELECT      DISTINCT inc.incident_id,
            date_part('year',inc.incident_date),
            vic.age_num,
            vic.sex_code AS VICTIM_SEX,
            oft.offense_category_name AS OFFENSE_CATEGORY,
            ori.countyname AS COUNTY
            
FROM        nibrs_victim as vic
JOIN        nibrs_offense as off
ON          off.incident_id = vic.incident_id
JOIN        nibrs_offense_type as oft
ON          oft.offense_type_id = off.offense_type_id
JOIN        nibrs_incident as inc
ON          inc.incident_id = vic.incident_id
JOIN        cde_agencies as ags
ON          ags.agency_id = inc.agency_id
JOIN        ori_to_fips as ori
ON          ori.ori9 = ags.ori

WHERE       vic.victim_type_id = 4
AND         inc.incident_date BETWEEN '2016-01-01' AND '2016-12-31';
'''

# %%
df = pd.read_sql(query, con=conn)
df.head(3).T
# Out:
#                                        0               1  \
# incident_id                     87264241        87264244
# date_part                           2016            2016
# age_num                               59              50
# victim_sex                             F               M
# offense_category  Larceny/Theft Offenses  Fraud Offenses
# county                            BURNET          BURNET
#
#                                        2
# incident_id                     87264248
# date_part                           2016
# age_num                               26
# victim_sex                             F
# offense_category  Larceny/Theft Offenses
# county                            BURNET

# %%
crime_df = df.groupby(['county']).incident_id.agg('count')
crime_df = crime_df.to_frame().reset_index()
crime_df = crime_df.rename({'incident_id': 'crime_cnt'}, axis='columns')
crime_df
# Out:
#           county  crime_cnt
# 0           BELL       3348
# 1          BEXAR        392
# 2       BRAZORIA       2994
# 3       BREWSTER         70
# 4         BURNET        342
# 5        CALHOUN        756
# 6        CAMERON          2
# 7         COLLIN      16800
# 8        CORYELL        111
# 9         DALLAS       4395
# 10       DE WITT        311
# 11        DENTON      10999
# 12        GOLIAD        200
# 13         GREGG       5563
# 14      HARDEMAN         63
# 15        HARDIN        383
# 16        HARRIS       1207
# 17       HIDALGO        301
# 18          HUNT        108
# 19    HUTCHINSON        360
# 20       JACKSON        311
# 21     JEFFERSON        177
# 22       JOHNSON       1365
# 23       KAUFMAN       2875
# 24       KENDALL        292
# 25         LAMAR         91
# 26      LAMPASAS        150
# 27        LAVACA        128
# 28          LEON         37
# 29       LUBBOCK       1421
# 30       MADISON         31
# 31      MCLENNAN       2102
# 32         MILAM         32
# 33    MONTGOMERY       3000
# 34   NACOGDOCHES       2473
# 35     OCHILTREE         47
# 36        PARKER       1667
# 37          POLK        797
# 38        POTTER      16635
# 39       RANDALL        103
# 40      ROCKWALL       1658
# 41          RUSK       2219
# 42  SAN PATRICIO        427
# 43      SAN SABA         49
# 44        SHELBY         28
# 45         SMITH       6283
# 46         STARR         32
# 47       TARRANT      49434
# 48     TOM GREEN       8971
# 49        TRAVIS        489
# 50      VICTORIA       4874
# 51        WALKER        854
# 52       WHARTON        744
# 53       WICHITA        145
# 54       WILLACY        115
# 55    WILLIAMSON       1598
# 56          WISE        206
# 57         YOUNG         33
# 58        ZAVALA        218

# %%
df.join(crime_df.set_index('county'), on='county')
# Out:
#         incident_id  date_part  age_num victim_sex  \
# 0          87264241     2016.0     59.0          F
# 1          87264244     2016.0     50.0          M
# 2          87264248     2016.0     26.0          F
# 3          87264256     2016.0     25.0          F
# 4          87264264     2016.0     26.0          M
# 5          87264268     2016.0     41.0          M
# 6          87264307     2016.0     33.0          M
# 7          87264319     2016.0     23.0          F
# 160788              Burglary/Breaking & Entering     POLK        797
# 160789                    Larceny/Theft Offenses     POLK        797
# 160790                          Assault Offenses     POLK        797
# 160791                    Larceny/Theft Offenses     POLK        797
# 160792  Destruction/Damage/Vandalism of Property     POLK        797
# 160793              Burglary/Breaking & Entering     POLK        797
# 160794              Burglary/Breaking & Entering     POLK        797
# 160795              Burglary/Breaking & Entering     POLK        797
# 160796              Burglary/Breaking & Entering     POLK        797
# 160797                    Larceny/Theft Offenses     POLK        797
# 160798                    Larceny/Theft Offenses     POLK        797
# 160799                          Assault Offenses     POLK        797
# 160800                    Larceny/Theft Offenses     POLK        797
# 160801                          Assault Offenses     POLK        797
# 160802                    Drug/Narcotic Offenses     POLK        797
# 160803                          Assault Offenses     POLK        797
# 160804              Burglary/Breaking & Entering     POLK        797
# 160805  Destruction/Damage/Vandalism of Property     POLK        797
# 160806  Destruction/Damage/Vandalism of Property     POLK        797
# 160807                          Assault Offenses     POLK        797
# 160808                    Counterfeiting/Forgery     POLK        797
# 160809                    Counterfeiting/Forgery     POLK        797
# 160810              Burglary/Breaking & Entering     POLK        797
# 160811              Burglary/Breaking & Entering     POLK        797
# 160812  Destruction/Damage/Vandalism of Property     POLK        797
# 160813                    Larceny/Theft Offenses     POLK        797
# 160814              Burglary/Breaking & Entering     POLK        797
# 160815              Burglary/Breaking & Entering     POLK        797
#
# [160816 rows x 7 columns]

# %%
df.head()
# Out:
#    incident_id  date_part  age_num victim_sex        offense_category   county
# 0     87264241     2016.0     59.0          F  Larceny/Theft Offenses   BURNET
# 1     87264244     2016.0     50.0          M          Fraud Offenses   BURNET
# 2     87264248     2016.0     26.0          F  Larceny/Theft Offenses   BURNET
# 3     87264256     2016.0     25.0          F        Assault Offenses  CAMERON
# 4     87264264     2016.0     26.0          M  Larceny/Theft Offenses  CAMERON

# %%
age_df = df[['victim_sex','age_num']]

# %%
age_df.columns = ['victim_sex','age_num']

axarr = age_df.hist(column='age_num', by ='victim_sex', bins=99, rwidth=0.9, sharex=True, sharey=True, layout = (1, 3), figsize=(15,5))

for ax in axarr.flatten():
    ax.set_xlabel("Age")
    ax.set_ylabel("Victim Count")

# %%
off_df = df[['victim_sex','offense_category']]

# %%
off_df.columns = ['victim_sex','offense_category']

axarr = off_df.hist(column='offense_category', by = 'victim_sex', bins=18, sharex=True, sharey=True, layout = (1, 3), figsize=(15,5))

for ax in axarr.flatten():
    ax.set_xlabel("Offense Category")
    ax.set_ylabel("Victim Count")

# %%
df['victim_sex'].value_counts()

# %%
df['offense_category'].unique()

# %%
df.groupby(['victim_sex','offense_category']).incident_id.agg('count')

# %%
hospitals = pd.read_csv('export.csv')
hospitals.head(3).T

# %%
hospitals['beds'] = hospitals['beds'].clip_lower(0)

# %%
hosp_cnt = hospitals.groupby('county').id.agg('count')

# %%
hosp_cnt = hosp_cnt.to_frame().reset_index()

# %%
hosp_cnt

# %%
test_merge = hospitals.merge(hosp_cnt,on='county')

# %%
test_merge.head(3).T

# %%
bed_cnt = hospitals.groupby('county').beds.agg('sum')

# %%
bed_cnt = bed_cnt.to_frame().reset_index()

# %%
bed_cnt

# %%
hosp = test_merge.merge(bed_cnt,on='county')

# %%
hosp.head(3).T

# %%
hosp = hosp.rename({'id_x': 'id', 'id_y': 'count', 'beds_x': 'beds', 'beds_y': 'bed_count'}, axis='columns')

# %%
hosp.head(3).T

# %%
hosp_merge = hosp[['county','count','bed_count']]

# %%
#df = df.merge(hosp_merge,on='county')
df = df.join(hosp_merge.set_index('county'), on='county')

# %%
df.head(3).T
